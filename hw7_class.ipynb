# %%
from matplotlib import pyplot as plt
import numpy as np
import tkinter as tk
from tkinter import filedialog

# %%
class SelectPlot(tk.Tk):
    def __init__(self):
        tk.Tk.__init__(self)
        self.createWidgets()
    def plot(self):
        self.filename=filedialog.askopenfilename(title = "select")
        lines=np.loadtxt(self.filename).transpose()
        plt.plot(lines[0],lines[1])
        plt.show()
    def createWidgets(self):
        self.findbutton= tk.Button(self,text='select',command=self.plot)
        self.findbutton.grid() 
app = SelectPlot()
app.title('6666')
app.mainloop()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-71-ce810b77cb48> in <module>()
#      11         self.findbutton= tk.Button(self,text='select',command=self.plot)
#      12         self.findbutton.grid()
# ---> 13 app = SelectPlot()
#      14 app.title('6666')
#      15 app.mainloop()
#
# <ipython-input-71-ce810b77cb48> in __init__(self)
#       2     def __init__(self):
#       3 #         tk.Tk.__init__(self)
# ----> 4         self.createWidgets()
#       5     def plot(self):
#       6         self.filename=filedialog.askopenfilename(title = "select")
#
# <ipython-input-71-ce810b77cb48> in createWidgets(self)
#       9         plt.show()
#      10     def createWidgets(self):
# ---> 11         self.findbutton= tk.Button(self,text='select',command=self.plot)
#      12         self.findbutton.grid()
#      13 app = SelectPlot()
#
# /usr/lib/python3.5/tkinter/__init__.py in __init__(self, master, cnf, **kw)
#    2215             overrelief, state, width
#    2216         """
# -> 2217         Widget.__init__(self, master, 'button', cnf, kw)
#    2218
#    2219     def flash(self):
#
# /usr/lib/python3.5/tkinter/__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2138             cnf = _cnfmerge((cnf, kw))
#    2139         self.widgetName = widgetName
# -> 2140         BaseWidget._setup(self, master, cnf)
#    2141         if self._tclCommands is None:
#    2142             self._tclCommands = []
#
# /usr/lib/python3.5/tkinter/__init__.py in _setup(self, master, cnf)
#    2116                 master = _default_root
#    2117         self.master = master
# -> 2118         self.tk = master.tk
#    2119         name = None
#    2120         if 'name' in cnf:
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# ...
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# /usr/lib/python3.5/tkinter/__init__.py in __getattr__(self, attr)
#    1955     def __getattr__(self, attr):
#    1956         "Delegate attribute access to the interpreter object"
# -> 1957         return getattr(self.tk, attr)
#    1958
#    1959 # Ideally, the classes Pack, Place and Grid disappear, the
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
